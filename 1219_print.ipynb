# %%
print("hello")

# %%
# 야구용어 >> mp3 파일로 출력

from gtts import gTTS
import os
import time

tFile='/content/drive/MyDrive/Colab Notebooks/Web_Scrapping/baseball_term.txt'
# tFile="/content/drive/MyDrive/로이터뉴스.txt"
fh=open(tFile,"r")
# myText=fh.read().replace("\n", '\n<break time="3s"/>')
# myText=fh.read().replace("\n"," ")
myText=fh.read()
# myText = fh.readlines()
# myText=str(myText[:4])

language='en'

output=gTTS(text=myText,lang=language,slow=False )
path='/content/drive/MyDrive/Colab Notebooks/Web_Scrapping/'
output.save(path+'output.mp3')
fh.close()
# os.getcwd()
os.system('start output.mp3')
